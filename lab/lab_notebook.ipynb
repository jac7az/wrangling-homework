# %% [markdown]
# # Web Scraping
#
# Lots of great data is available online, but available through inconveniently formatted web pages. When this is the case, sometimes you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with and how it is used.
#
# We'll be scraping data about used cars in Charlottesville from Craigslist, particularly this page: https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0

# %% [markdown]
# We'll use the `requests` package to get web pages off the Internet and into Python. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville. To use requests, you pass a `url` for the page you want and a `header` that controls how you appear to the server to `requests.get`:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} # How we wish to appear to CL
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0' # The page we want to scrape
raw = requests.get(url,headers=header) # Get page

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](./src/craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](./src/craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](./src/listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tags, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.
#
# What I do is look at the rendered page, find the text I want and copy it, then search for that text in the HTML code that the computer sees. When I find the text I want, I look for the tag nearby. Here, it's `cl-static-search-result`: That's what I'll want beautifulSoup to search for.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings of the kind we want

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# Parsing the entries can be a challenge! We have to go back to what a listing looks like, and look at the tags within the listing. They're typically `div` tags with a `class` like price or location. You then have to experiment a bit with `.find` and the HTML to make sure you're getting the information you want. For each listing, the `.find` method to search within the listing record for specific information, but it's typically still wrapped in the tag. To get the real information we want, we can then use `.get_text()`. I end up using a code chunk to experiment and play with a record to make sure I'm getting as close to what I want as possible.
#
# In the code below, two more things happen. You don't need to do them in your work, but they're helpful to know about.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, if possible, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})
data
# Out:
# [{'title': '1999 chevy blazer 4wd',
#   'price': '$2,200',
#   'year': '1999',
#   'link': 'https://charlottesville.craigslist.org/cto/d/new-canton-1999-chevy-blazer-4wd/7824374635.html',
#   'brand': 'chevy'},
#  {'title': '1997 honda accord lx 2 door',
#   'price': '$2,800',
#   'year': '1997',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1997-honda-accord-lx/7824233059.html',
#   'brand': 'honda'},
#  {'title': '2004 toyota tundra sr5 for sale -  manual transmission v6 model',
#   'price': '$6,500',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/afton-2004-toyota-tundra-sr5-for-sale/7824232127.html',
#   'brand': 'toyota'},
#  {'title': '2006 cadillac cts 107,086 miles only',
#   'price': '$2,950',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2006-cadillac-cts-miles/7824205698.html',
#   'brand': 'cadillac'},
#  {'title': 'chevy',
#   'price': '$6,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/waynesboro-chevy/7824186332.html',
#   'brand': 'chevy'},
#  {'title': '1966 chevrolet corvair corsa sport coupe',
#   'price': '$5,000',
#   'year': '1966',
#   'link': 'https://charlottesville.craigslist.org/cto/d/bremo-bluff-1966-chevrolet-corvair/7824173984.html',
#   'brand': 'chevrolet'},
#  {'title': '1979 oldsmobile cutlass supreme broughm',
#   'price': '$2,800',
#   'year': '1979',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1979-oldsmobile-cutlass/7824160442.html',
#   'brand': 'missing'},
#  {'title': '2009 honda fit sport',
#   'price': '$3,400',
#   'year': '2009',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2009-honda-fit-sport/7824096220.html',
#   'brand': 'honda'},
#  {'title': '2001 mercedes e320',
#   'price': '$2,000',
#   'year': '2001',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2001-mercedes-e320/7823993772.html',
#   'brand': 'missing'},
#  {'title': '2012 honda civic lx',
#   'price': '$5,900',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2012-honda-civic-lx/7823876536.html',
#   'brand': 'honda'},
#  {'title': 'toyota camry 2008',
#   'price': '$3,000',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-toyota-camry-2008/7823636080.html',
#   'brand': 'toyota'},
#  {'title': 'toyota tundra 2013',
#   'price': '$16,000',
#   'year': '2013',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-toyota-tundra-2013/7823632266.html',
#   'brand': 'toyota'},
#  {'title': 'chev van',
#   'price': '$4,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/palmyra-chev-van/7823632242.html',
#   'brand': 'missing'},
#  {'title': '1994 dodge ram b1500 van',
#   'price': '$9,750',
#   'year': '1994',
#   'link': 'https://charlottesville.craigslist.org/cto/d/louisa-1994-dodge-ram-b1500-van/7823474959.html',
#   'brand': 'dodge'},
#  {'title': '2008 ford f350 super duty',
#   'price': '$9,500',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/north-garden-2008-ford-f350-super-duty/7823252225.html',
#   'brand': 'ford'},
#  {'title': '2006 acura tl',
#   'price': '$3,000',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/barboursville-2006-acura-tl/7823201713.html',
#   'brand': 'acura'},
#  {'title': 'ford 1992 mustang gt',
#   'price': '$18,500',
#   'year': '1992',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-ford-1992-mustang-gt/7822685906.html',
#   'brand': 'ford'},
#  {'title': '1981 volkswagen diesel rabbit - pickup - running needs work',
#   'price': '$6,500',
#   'year': '1981',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1981-volkswagen-diesel/7822650593.html',
#   'brand': 'volkswagen'},
#  {'title': '2007 nissan altima s',
#   'price': '$2,900',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2007-nissan-altima/7822632171.html',
#   'brand': 'missing'},
#  {'title': '2012 jeep patriot 4x4',
#   'price': '$6,250',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/lyndhurst-2012-jeep-patriot-4x4/7822525934.html',
#   'brand': 'jeep'},
#  {'title': '2010 honda odessey',
#   'price': '$3,000',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/palmyra-2010-honda-odessey/7822427237.html',
#   'brand': 'honda'},
#  {'title': '2008 kia sedona lx 4door',
#   'price': '$2,500',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/barboursville-2008-kia-sedona-lx-4door/7822425347.html',
#   'brand': 'kia'},
#  {'title': 'mitsubishi eclipse gt, 2008',
#   'price': '$6,800',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-mitsubishi-eclipse-gt/7822328562.html',
#   'brand': 'mitsubishi'},
#  {'title': '2007 jeep wrangler - manual',
#   'price': '$8,700',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2007-jeep-wrangler/7822281686.html',
#   'brand': 'jeep'},
#  {'title': 'classic chevy cavalier',
#   'price': '$2,900',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/orange-classic-chevy-cavalier/7822212020.html',
#   'brand': 'chevy'},
#  {'title': '2017 audi a4 prestige',
#   'price': '$11,000',
#   'year': '2017',
#   'link': 'https://charlottesville.craigslist.org/cto/d/shipman-2017-audi-a4-prestige/7822176883.html',
#   'brand': 'audi'},
#  {'title': '2004 toyota celica',
#   'price': '$5,200',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2004-toyota-celica/7822174332.html',
#   'brand': 'toyota'},
#  {'title': '2012 ford mustang premium v6 coupe',
#   'price': '$13,500',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/bremo-bluff-2012-ford-mustang-premium/7821827034.html',
#   'brand': 'ford'},
#  {'title': '2017 honda accord hybrid',
#   'price': '$14,000',
#   'year': '2017',
#   'link': 'https://charlottesville.craigslist.org/cto/d/montpelier-station-2017-honda-accord/7821612708.html',
#   'brand': 'honda'},
#  {'title': 'toyota tacoma 2000',
#   'price': '$10,700',
#   'year': '2000',
#   'link': 'https://charlottesville.craigslist.org/cto/d/quinque-toyota-tacoma-2000/7821590907.html',
#   'brand': 'toyota'},
#  {'title': '1989 chevrolet silverado 4x4',
#   'price': '$14,500',
#   'year': '1989',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1989-chevrolet/7821464016.html',
#   'brand': 'chevrolet'},
#  {'title': '2004 lincoln ls v8',
#   'price': '$3,450',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/shipman-2004-lincoln-ls-v8/7821350698.html',
#   'brand': 'missing'},
#  {'title': '2003 volkswagen passat w8 4 motion',
#   'price': '$2,600',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/shipman-2003-volkswagen-passat-w8-motion/7821345128.html',
#   'brand': 'volkswagen'},
#  {'title': '2008 bmw x5 4.8i',
#   'price': '$10,000',
#   'year': '2008',
#   'link': 'https://charlottesville.craigslist.org/cto/d/earlysville-2008-bmw-x5-48i/7821271169.html',
#   'brand': 'bmw'},
#  {'title': '2014 ford fusion daily driven',
#   'price': '$4,000',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/haywood-2014-ford-fusion-daily-driven/7821246226.html',
#   'brand': 'ford'},
#  {'title': '2007 mercury mariner',
#   'price': '$3,500',
#   'year': '2007',
#   'link': 'https://charlottesville.craigslist.org/cto/d/haywood-2007-mercury-mariner/7820892591.html',
#   'brand': 'missing'},
#  {'title': '2015 nissan altima',
#   'price': '$3,500',
#   'year': '2015',
#   'link': 'https://charlottesville.craigslist.org/cto/d/richmond-2015-nissan-altima/7820703591.html',
#   'brand': 'missing'},
#  {'title': '2021 honda crv',
#   'price': '$29,000',
#   'year': '2021',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2021-honda-crv/7820682302.html',
#   'brand': 'honda'},
#  {'title': '2006 honda pilot exl fwd',
#   'price': '$4,700',
#   'year': '2006',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2006-honda-pilot-exl-fwd/7820635670.html',
#   'brand': 'honda'},
#  {'title': '2003 dodge 1500',
#   'price': '$4,000',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/roseland-2003-dodge-1500/7820534784.html',
#   'brand': 'dodge'},
#  {'title': '2003 ford f250 6.0',
#   'price': '$18,000',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/roseland-2003-ford-f250-60/7820533171.html',
#   'brand': 'ford'},
#  {'title': '1957 international a series pickup truck',
#   'price': '$5,250',
#   'year': '1957',
#   'link': 'https://charlottesville.craigslist.org/cto/d/woodberry-forest-1957-international/7820520241.html',
#   'brand': 'missing'},
#  {'title': '1961 mg mga roadster',
#   'price': '$3,250',
#   'year': '1961',
#   'link': 'https://charlottesville.craigslist.org/cto/d/woodberry-forest-1961-mg-mga-roadster/7820520061.html',
#   'brand': 'missing'},
#  {'title': '2014 acura mdx awd',
#   'price': '$7,500',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2014-acura-mdx-awd/7820090695.html',
#   'brand': 'acura'},
#  {'title': '2014 honda odyssey van black',
#   'price': '$13,000',
#   'year': '2014',
#   'link': 'https://charlottesville.craigslist.org/cto/d/scottsville-2014-honda-odyssey-van-black/7820090166.html',
#   'brand': 'honda'},
#  {'title': '1984 gmc 3500',
#   'price': '$7,000',
#   'year': '1984',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1984-gmc-3500/7820076593.html',
#   'brand': 'gmc'},
#  {'title': '2010 honda crv lx',
#   'price': '$6,500',
#   'year': '2010',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2010-honda-crv-lx/7820052637.html',
#   'brand': 'honda'},
#  {'title': '2018 mercedes sprinter 2500 crew van',
#   'price': '$62,800',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/barboursville-2018-mercedes-sprinter/7820040769.html',
#   'brand': 'missing'},
#  {'title': '2009 bmw 328i coupe',
#   'price': '$7,500',
#   'year': '2009',
#   'link': 'https://charlottesville.craigslist.org/cto/d/barboursville-2009-bmw-328i-coupe/7819945910.html',
#   'brand': 'bmw'},
#  {'title': '1997 nissan pathfinder',
#   'price': '$3,500',
#   'year': '1997',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-1997-nissan-pathfinder/7819380167.html',
#   'brand': 'missing'},
#  {'title': '2018 tesla model s 75d awd manufacture warranty',
#   'price': '$26,900',
#   'year': '2018',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2018-tesla-model-75d-awd/7819302933.html',
#   'brand': 'tesla'},
#  {'title': '2004 chevy silverado',
#   'price': '$3,000',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2004-chevy-silverado/7819002309.html',
#   'brand': 'chevy'},
#  {'title': 'a sweet sedan avalon xle plus',
#   'price': '$24,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-sweet-sedan-avalon-xle/7818676493.html',
#   'brand': 'missing'},
#  {'title': 'gmc sierra 3500hd 6.6 duramax diesel dually',
#   'price': '$26,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-gmc-sierra-3500hd-66/7818481465.html',
#   'brand': 'gmc'},
#  {'title': '2012 nissan versa sl',
#   'price': '$3,200',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2012-nissan-versa-sl/7818255369.html',
#   'brand': 'missing'},
#  {'title': 'ford e-350 2003 quigley 4x4 ambulance camper van',
#   'price': '$49,500',
#   'year': '2003',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-ford-quigley-4x4/7818176803.html',
#   'brand': 'ford'},
#  {'title': '2012 lexus rx450h awd',
#   'price': '$10,950',
#   'year': '2012',
#   'link': 'https://charlottesville.craigslist.org/cto/d/henrico-2012-lexus-rx450h-awd/7818114210.html',
#   'brand': 'lexus'},
#  {'title': '2013 honda ridgeline rtl 4wd',
#   'price': '$7,900',
#   'year': '2013',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2013-honda-ridgeline/7817681802.html',
#   'brand': 'honda'},
#  {'title': '1963 /1965 triumph tr4 convertible',
#   'price': '$2,250',
#   'year': '1963',
#   'link': 'https://charlottesville.craigslist.org/cto/d/woodberry-forest-triumph-tr4-convertible/7817663151.html',
#   'brand': 'missing'},
#  {'title': '1989 xj wrangler',
#   'price': '$4,999',
#   'year': '1989',
#   'link': 'https://charlottesville.craigslist.org/cto/d/white-hall-1989-xj-wrangler/7817049789.html',
#   'brand': 'missing'},
#  {'title': '2013 jeep grand cherokee - overland - 4wd (replaced motor)',
#   'price': '$8,750',
#   'year': '2013',
#   'link': 'https://charlottesville.craigslist.org/cto/d/crozet-2013-jeep-grand-cherokee/7816766515.html',
#   'brand': 'jeep'},
#  {'title': '2004 lexus sc 430 convertible',
#   'price': '$11,400',
#   'year': '2004',
#   'link': 'https://charlottesville.craigslist.org/cto/d/charlottesville-2004-lexus-sc-430/7816110681.html',
#   'brand': 'lexus'}]

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
#df.to_csv('./src/craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (62, 6)
#                                                title  price    year  \
# 0                              1999 chevy blazer 4wd   2200  1999.0
# 1                        1997 honda accord lx 2 door   2800  1997.0
# 2  2004 toyota tundra sr5 for sale -  manual tran...   6500  2004.0
# 3               2006 cadillac cts 107,086 miles only   2950  2006.0
# 4                                              chevy   6000     NaN
#
#                                                 link     brand   age
# 0  https://charlottesville.craigslist.org/cto/d/n...     chevy  26.0
# 1  https://charlottesville.craigslist.org/cto/d/c...     honda  28.0
# 2  https://charlottesville.craigslist.org/cto/d/a...    toyota  21.0
# 3  https://charlottesville.craigslist.org/cto/d/c...  cadillac  19.0
# 4  https://charlottesville.craigslist.org/cto/d/w...     chevy   NaN

# %% [markdown]
# With the data in and wrangled, we can now do some analysis:

# %%
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count       62.000000
# mean      9510.467742
# std      10767.372320
# min       2000.000000
# 25%       3287.500000
# 50%       6125.000000
# 75%      10887.500000
# max      62800.000000
# Name: price, dtype: float64
# count    57.000000
# mean     22.456140
# std      14.458154
# min       4.000000
# 25%      13.000000
# 50%      18.000000
# 75%      25.000000
# max      68.000000
# Name: age, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#            price                                                          \
#            count          mean           std      min       25%      50%
# brand
# audi         1.0  37000.000000           NaN  37000.0  37000.00  37000.0
# bmw          3.0  19966.666667  20813.537261   7900.0   7950.00   8000.0
# chevrolet    4.0  10875.000000   9393.038202   3000.0   3375.00   9000.0
# chevy        3.0  11616.666667  11515.677719   4450.0   4975.00   5500.0
# dodge        1.0  18900.000000           NaN  18900.0  18900.00  18900.0
# ford         3.0  21333.333333  29173.332572   3500.0   4500.00   5500.0
# gmc          2.0  16475.000000  13470.384182   6950.0  11712.50  16475.0
# honda        5.0   5629.800000   2372.328013   2300.0   4700.00   5900.0
# jeep         2.0   9500.000000      0.000000   9500.0   9500.00   9500.0
# lexus        2.0  11175.000000    318.198052  10950.0  11062.50  11175.0
# missing     14.0  10089.214286  16148.241324   2000.0   3312.50   4650.0
# mitsubishi   1.0   7300.000000           NaN   7300.0   7300.00   7300.0
# subaru       1.0   3900.000000           NaN   3900.0   3900.00   3900.0
# toyota       4.0   9549.750000   7072.121340   2199.0   4299.75   9500.0
#
#
#                  75%      max
# brand
# audi        37000.00  37000.0
# bmw         26000.00  44000.0
# chevrolet   16500.00  22500.0
# chevy       15200.00  24900.0
# dodge       18900.00  18900.0
# ford        30250.00  55000.0
# gmc         21237.50  26000.0
# honda        6500.00   8749.0
# jeep         9500.00   9500.0
# lexus       11287.50  11400.0
# missing      6749.75  62800.0
# mitsubishi   7300.00   7300.0
# subaru       3900.00   3900.0
# toyota      14750.00  17000.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#              age
#            count       mean        std   min   25%   50%   75%   max
# brand
# audi         1.0   6.000000        NaN   6.0   6.0   6.0   6.0   6.0
# bmw          2.0  15.000000   1.414214  14.0  14.5  15.0  15.5  16.0
# chevrolet    4.0  44.000000  16.000000  36.0  36.0  36.0  44.0  68.0
# chevy        3.0  20.000000  12.124356   7.0  14.5  22.0  26.5  31.0
# dodge        1.0  27.000000        NaN  27.0  27.0  27.0  27.0  27.0
# ford         3.0  22.666667   1.154701  22.0  22.0  22.0  23.0  24.0
# gmc          1.0  27.000000        NaN  27.0  27.0  27.0  27.0  27.0
# honda        5.0  18.000000   9.000000  10.0  13.0  15.0  19.0  33.0
# jeep         2.0  22.000000  14.142136  12.0  17.0  22.0  27.0  32.0
# lexus        2.0  17.000000   5.656854  13.0  15.0  17.0  19.0  21.0
# missing     11.0  30.636364  23.585049   7.0  12.0  20.0  49.0  68.0
# mitsubishi   1.0  17.000000        NaN  17.0  17.0  17.0  17.0  17.0
# subaru       1.0  11.000000        NaN  11.0  11.0  11.0  11.0  11.0
# toyota       4.0  15.500000   3.109126  12.0  13.5  15.5  17.5  19.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   0.783367 -0.196806
# log_age    -0.196806  0.382606
#            log_price   log_age
# log_price   1.000000 -0.376511
# log_age    -0.376511  1.000000

# %% [markdown]
# ## The Lab:
#
#
# 1. Pick something else on Craigslist besides used cars: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of basic EDA you'd do with it.
# 2. Get your search results of interest using `requests` and extract data from them using `beautifulSoup`, using code similar to what's above.
# 3. Wrangle your data into a dataframe and do some basic descriptions and plots. Try to find some interesting relationships or stories to tell about your data.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import re

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'}
url = 'https://charlottesville.craigslist.org/search/cla?purveyor=owner#search=1~gallery~0~6'
raw = requests.get(url,headers=header)

# %%
from bs4 import BeautifulSoup as soup
bsObj = soup(raw.content,'html.parser')
listings = bsObj.find_all(class_="cl-static-search-result")

# %%
clothing={'dress':['dress','dresses','skirt','skirts','gown','ballgown','gowns'],
           'warmer wear':['coat','coats','jacket','jackets','hoodie','hoodies','sweater','sweaters'],
          'upper body':['shirt','shirts','blouse','blouses'],
          'shoes':['shoe','shoes','sneakers','platform','heels','boots'],
           'pants':['jeans','pants','pant','suit pants'],
           'accessories':['ties','jewelry','bracelets','bracelet','earrings','necklace','necklaces','headband','hairties'],
          'bags':['bags','wallet','purse','purses','wallets','bag','pouches','pouch']}
items=[item for item in clothing.values()]
things=[]
data=[]
for thing in items:
  for i in thing:
    things.append(i)

for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower().strip()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    try:
      location=listings[k].find('div',class_='location').get_text().lower().strip()
    except AttributeError:
      location='unknown'
    words = title.split()
    hits = [word.lower() for word in words if word in things]
    if len(hits) == 0:
      article = 'other'
    else:
      product=hits[0].lower()
      for category,i in clothing.items():
        if product in clothing.get(category):
          article=category
    #
    data.append({'title':title,'price':price,'category':article,'location':location,'link':link})
data
# Out:
# [{'title': 'karate tae kwon do uniforms brand new',
#   'price': '$24',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-karate-tae-kwon-do/7818355945.html'},
#  {'title': 'solid wooden shoe shelf',
#   'price': '$60',
#   'category': 'shoes',
#   'location': 'crozet/charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/greenwood-solid-wooden-shoe-shelf/7821284554.html'},
#  {'title': 'brand new mens nike court vision shoes',
#   'price': '$80',
#   'category': 'shoes',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-brand-new-mens-nike/7819601303.html'},
#  {'title': 'vintage manhattan portage nyc messenger shoulder bag large',
#   'price': '$70',
#   'category': 'bags',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vintage-manhattan/7822055264.html'},
#  {'title': 'distressed double front carhartt pants',
#   'price': '$20',
#   'category': 'pants',
#   'location': 'mineral',
#   'link': 'https://charlottesville.craigslist.org/clo/d/mineral-distressed-double-front/7824141165.html'},
#  {'title': "three women's leather belts",
#   'price': '$20',
#   'category': 'other',
#   'location': 'palmyra',
#   'link': 'https://charlottesville.craigslist.org/clo/d/palmyra-three-womens-leather-belts/7822236893.html'},
#  {'title': 'louis vuitton duffel bag and purse well loved,  authentic',
#   'price': '$123,456,789',
#   'category': 'bags',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-louis-vuitton-duffel/7823434786.html'},
#  {'title': 'dkny xlarge chino red heritage saffiano & logo plaque new w tags crossbody purse',
#   'price': '$80',
#   'category': 'bags',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-dkny-xlarge-chino-red/7824085546.html'},
#  {'title': 'bag of womens t shirts',
#   'price': '$20',
#   'category': 'bags',
#   'location': 'rhoadesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/unionville-bag-of-womens-shirts/7824064001.html'},
#  {'title': '2 n 1 red sequin top',
#   'price': '$10',
#   'category': 'other',
#   'location': 'rhoadesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/orange-n-red-sequin-top/7824051245.html'},
#  {'title': 'wedding dress',
#   'price': '$100',
#   'category': 'dress',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-wedding-dress/7823990756.html'},
#  {'title': 'dinkles glide marching band shoes',
#   'price': '$29',
#   'category': 'shoes',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/scottsville-dinkles-glide-marching-band/7821971171.html'},
#  {'title': 'wedding dress - alessandra rinaudo - $350 obo',
#   'price': '$350',
#   'category': 'dress',
#   'location': 'downtown, charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-wedding-dress/7821185029.html'},
#  {'title': "adidas men's essential tricot zip pants in black",
#   'price': '$25',
#   'category': 'pants',
#   'location': 'forest lakes',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-adidas-mens-essential/7819791460.html'},
#  {'title': '2 pair red tag levis straight leg',
#   'price': '$50',
#   'category': 'other',
#   'location': 'brightwood',
#   'link': 'https://charlottesville.craigslist.org/clo/d/brightwood-pair-red-tag-levis-straight/7823712352.html'},
#  {'title': 'vintage ties',
#   'price': '$5',
#   'category': 'accessories',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/troy-vintage-ties/7818114764.html'},
#  {'title': 'us navy pea coat (brand new w/ tags)',
#   'price': '$50',
#   'category': 'warmer wear',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-us-navy-pea-coat-brand/7820744882.html'},
#  {'title': 'mens boots',
#   'price': '$100',
#   'category': 'shoes',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-mens-boots/7823616336.html'},
#  {'title': 'sp5der hoodie',
#   'price': '$100',
#   'category': 'warmer wear',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-sp5der-hoodie/7823520280.html'},
#  {'title': 'hollister jeans',
#   'price': '$10',
#   'category': 'pants',
#   'location': 'louisa',
#   'link': 'https://charlottesville.craigslist.org/clo/d/louisa-hollister-jeans/7823489050.html'},
#  {'title': 'adidas nizza platform mid w blue 8 1/2',
#   'price': '$40',
#   'category': 'shoes',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-adidas-nizza-platform-mid-blue-1/7823469401.html'},
#  {'title': 'sag harbor full length skirt for a cruise or beach',
#   'price': '$8',
#   'category': 'dress',
#   'location': 'earlysville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-sag-harbor-full-length/7818775705.html'},
#  {'title': 'calling all design lovers & collectors! 🛋️✨',
#   'price': '$1',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-calling-all-design/7823419678.html'},
#  {'title': '> t-shirt - "spirit of america" : never worn, exc cond, 100% cotton <',
#   'price': '$0',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-shirt-spirit-of-america/7820313069.html'},
#  {'title': '> hemp t-shirts - never worn, 100% cotton, exc cond <',
#   'price': '$0',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-hemp-shirts-never-worn/7820313042.html'},
#  {'title': "> vintage womens' winter coats - (2), exc cond <",
#   'price': '$0',
#   'category': 'warmer wear',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vintage-womens-winter/7820313016.html'},
#  {'title': '> leather jacket - s.western style : mens size 40r, exc cond <',
#   'price': '$0',
#   'category': 'warmer wear',
#   'location': 'charlotesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-leather-jacket-swestern/7820312995.html'},
#  {'title': '> leather jacket - mens xxl, formal or casual use, exc cond <',
#   'price': '$0',
#   'category': 'warmer wear',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-leather-jacket-mens-xxl/7820312969.html'},
#  {'title': '> wedding gown w/ hand-beaded waist, exc cond <',
#   'price': '$0',
#   'category': 'dress',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-wedding-gown-hand/7820312644.html'},
#  {'title': 'new "etnies" shoes',
#   'price': '$25',
#   'category': 'shoes',
#   'location': 'gordonsville, va.',
#   'link': 'https://charlottesville.craigslist.org/clo/d/somerset-new-etnies-shoes/7820975402.html'},
#  {'title': "new lands' end girls coat large 14 stormer snowboard parka color block",
#   'price': '$30',
#   'category': 'warmer wear',
#   'location': 'earlysville / charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-new-lands-end-girls-coat/7823232649.html'},
#  {'title': 'girls large 10/12 cherokee outfit top & pants black new with tags',
#   'price': '$20',
#   'category': 'pants',
#   'location': 'earlysville / charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-girls-large-cherokee-outfit/7823232532.html'},
#  {'title': "patagonia women's xs polartec fleece 1/4 re-tool snap pullover jacket",
#   'price': '$40',
#   'category': 'warmer wear',
#   'location': 'earlysville / charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-patagonia-womens-xs/7823232462.html'},
#  {'title': 'harley-davidson long sleeve shirt, xl, blue, new w/tags',
#   'price': '$40',
#   'category': 'other',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-harley-davidson-long-sleeve/7823179051.html'},
#  {'title': 'harley-davidson, new t shirts, xl',
#   'price': '$20',
#   'category': 'other',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-harley-davidson-new-shirts-xl/7823177894.html'},
#  {'title': "seafoam quilted woman's coat size s like new",
#   'price': '$25',
#   'category': 'warmer wear',
#   'location': 'earlysville / charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-seafoam-quilted-womans-coat/7823160759.html'},
#  {'title': 'vintage christian dior nightgown',
#   'price': '$45',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vintage-christian-dior/7815186624.html'},
#  {'title': 'kelley hand or shoulder purse',
#   'price': '$5',
#   'category': 'bags',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/troy-kelley-hand-or-shoulder-purse/7822978857.html'},
#  {'title': "allen edmonds men's shoes",
#   'price': '$60',
#   'category': 'shoes',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-allen-edmonds-mens-shoes/7816773385.html'},
#  {'title': 'black leather jacket - xl',
#   'price': '$35',
#   'category': 'warmer wear',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-black-leather-jacket-xl/7816772597.html'},
#  {'title': "allen edmonds men's shoes -11d",
#   'price': '$75',
#   'category': 'shoes',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-allen-edmonds-mens/7821306137.html'},
#  {'title': 'aviator bomber avirex a-2 leather jacket, size 38',
#   'price': '$175',
#   'category': 'other',
#   'location': 'charlottesville - ivy',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-aviator-bomber-avirex-2/7822567311.html'},
#  {'title': '100% wool/fur ladies coat',
#   'price': '$60',
#   'category': 'warmer wear',
#   'location': "c'ville",
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-100-wool-fur-ladies-coat/7822414566.html'},
#  {'title': 'windsor black bodycon dress',
#   'price': '$15',
#   'category': 'dress',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-windsor-black-bodycon/7822354144.html'},
#  {'title': 'windsor navy blue with silver sparkles prom dress size small',
#   'price': '$45',
#   'category': 'dress',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-windsor-navy-blue-with/7822170539.html'},
#  {'title': 'brand new nike air monarch iv men shoes',
#   'price': '$60',
#   'category': 'shoes',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-brand-new-nike-air/7817349569.html'},
#  {'title': 'old skool vans',
#   'price': '$50',
#   'category': 'other',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-old-skool-vans/7817568453.html'},
#  {'title': "vintage leather women's coat, etienne aigner large",
#   'price': '$39',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vintage-leather-womens/7818854558.html'},
#  {'title': "statutes black strappy heels size 7 women's 3 1/2 heel",
#   'price': '$5',
#   'category': 'shoes',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/fredericksburg-statutes-black-strappy/7819400439.html'},
#  {'title': 'caparros silver formal wedges womens shoes 6 1/2',
#   'price': '$5',
#   'category': 'shoes',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/fredericksburg-caparros-silver-formal/7819389208.html'},
#  {'title': "mens and women's $30 for all",
#   'price': '$30',
#   'category': 'other',
#   'location': 'crozet',
#   'link': 'https://charlottesville.craigslist.org/clo/d/greenwood-mens-and-womens-30-for-all/7814916262.html'},
#  {'title': "men's dress pants",
#   'price': '$20',
#   'category': 'dress',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-mens-dress-pants/7821449346.html'},
#  {'title': 'vera pella leather purse/backpack.',
#   'price': '$50',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vera-pella-leather/7814133355.html'},
#  {'title': 'jack georges leather briefcase',
#   'price': '$220',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-jack-georges-leather/7821308804.html'},
#  {'title': 'new size 2 simple wedding dress a line',
#   'price': '$150',
#   'category': 'dress',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-new-size-simple-wedding/7821204863.html'},
#  {'title': 'sneakers  giuseppe zanotti',
#   'price': '$220',
#   'category': 'shoes',
#   'location': 'greeene',
#   'link': 'https://charlottesville.craigslist.org/clo/d/quinque-sneakers-giuseppe-zanotti/7821191245.html'},
#  {'title': 'article modern ottoman',
#   'price': '$150',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-article-modern-ottoman/7821086569.html'},
#  {'title': 'new nike air pagasus - size 9.5',
#   'price': '$50',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-new-nike-air-pagasus/7821070341.html'},
#  {'title': 'jos a. banks leather jacket  large',
#   'price': '$100',
#   'category': 'warmer wear',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/middlebrook-jos-banks-leather-jacket/7820985179.html'},
#  {'title': 'adidas youth m 11-12 unisex shorts black white',
#   'price': '$10',
#   'category': 'other',
#   'location': 'earlysville / charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-adidas-youth-unisex-shorts/7820970633.html'},
#  {'title': 'youth girls unisex? 11-12 m adidas track pants climacool black white',
#   'price': '$15',
#   'category': 'pants',
#   'location': 'earlysville / charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-youth-girls-unisex-adidas/7820970536.html'},
#  {'title': 'jordans',
#   'price': '$200',
#   'category': 'other',
#   'location': 'cville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-jordans/7820700923.html'},
#  {'title': "jordan's",
#   'price': '$175',
#   'category': 'other',
#   'location': 'cville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-jordans/7820700495.html'},
#  {'title': 'harley-davidson leather jacket xl nevada 98122-98vm/002l',
#   'price': '$425',
#   'category': 'warmer wear',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-harley-davidson-leather-jacket/7820406311.html'},
#  {'title': 'harley-davidson circle banner crew sweatshirt xl new with tags',
#   'price': '$45',
#   'category': 'other',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-harley-davidson-circle-banner/7820405905.html'},
#  {'title': 'vintage ll bean medium leather bomber w/mouton lambskin collar',
#   'price': '$400',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vintage-ll-bean-medium/7813357698.html'},
#  {'title': "men's large columbia sportswear 3-in-1 ski jacket- excellent condition",
#   'price': '$125',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-mens-large-columbia/7813357494.html'},
#  {'title': 'g/fore mens golf shoes 10.5',
#   'price': '$155',
#   'category': 'shoes',
#   'location': 'ivy',
#   'link': 'https://charlottesville.craigslist.org/clo/d/ivy-fore-mens-golf-shoes-105/7819937837.html'},
#  {'title': 'g shock ga-2100',
#   'price': '$115',
#   'category': 'other',
#   'location': 'ivy',
#   'link': 'https://charlottesville.craigslist.org/clo/d/ivy-shock-ga-2100/7819937211.html'},
#  {'title': 'crib (pottery barn)',
#   'price': '$165',
#   'category': 'other',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-crib-pottery-barn/7819794916.html'},
#  {'title': 'designer handbags',
#   'price': '$45',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-designer-handbags/7815558196.html'},
#  {'title': 'dresses',
#   'price': '$1,243',
#   'category': 'dress',
#   'location': 'fork union',
#   'link': 'https://charlottesville.craigslist.org/clo/d/bremo-bluff-dresses/7816444721.html'},
#  {'title': 'nike air force 1 mid',
#   'price': '$150',
#   'category': 'other',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/culpeper-nike-air-force-mid/7812286181.html'},
#  {'title': "$300 nice almost new jordan's",
#   'price': '$300',
#   'category': 'other',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/orange-300-nice-almost-new-jordans/7814205916.html'},
#  {'title': 'zamberlan trail lite evo gtx mens hiking boots, new in box!',
#   'price': '$149',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-zamberlan-trail-lite/7818955975.html'},
#  {'title': 'stetson hat - red wool: eddie bauer',
#   'price': '$20',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-stetson-hat-red-wool/7818854841.html'},
#  {'title': 'artisan pottery tea set - seven pieces',
#   'price': '$30',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-artisan-pottery-tea-set/7818854708.html'},
#  {'title': 'vintage ceramics decor: choose from 5 charming items',
#   'price': '$10',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vintage-ceramics-decor/7818853031.html'},
#  {'title': 'suede redskins coat',
#   'price': '$350',
#   'category': 'warmer wear',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-suede-redskins-coat/7818852777.html'},
#  {'title': 'victorian bustle slip',
#   'price': '$65',
#   'category': 'other',
#   'location': 'culpeper',
#   'link': 'https://charlottesville.craigslist.org/clo/d/culpeper-victorian-bustle-slip/7811763886.html'},
#  {'title': 'handmade theater costume ladies size 18',
#   'price': '$15',
#   'category': 'other',
#   'location': 'earlysville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-handmade-theater-costume/7811486373.html'},
#  {'title': 'harley-davidson vest-primary, mens, blue, x-large, new with tags',
#   'price': '$50',
#   'category': 'other',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-harley-davidson-vest-primary/7818753670.html'},
#  {'title': 'heeled white pump',
#   'price': '$10',
#   'category': 'other',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-heeled-white-pump/7818558756.html'},
#  {'title': 'heeled black pump',
#   'price': '$10',
#   'category': 'other',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-heeled-black-pump/7818557143.html'},
#  {'title': 'vintage',
#   'price': '$50',
#   'category': 'other',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vintage/7811980624.html'},
#  {'title': 'nautica women’s down coat',
#   'price': '$20',
#   'category': 'warmer wear',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-nautica-womens-down-coat/7817777236.html'},
#  {'title': 'men’s northface fleece jacket',
#   'price': '$10',
#   'category': 'warmer wear',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-mens-northface-fleece/7817755611.html'},
#  {'title': 'boys / girls winter coat size 6/7 ($20)',
#   'price': '$20',
#   'category': 'warmer wear',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-boys-girls-winter-coat-size/7812996370.html'},
#  {'title': 'boys / girls winter coat/jacket size 8/10 ($22)',
#   'price': '$22',
#   'category': 'other',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-boys-girls-winter-coat/7812996168.html'},
#  {'title': 'boys / girls winter coat/jacket size 8 ($22)',
#   'price': '$22',
#   'category': 'other',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-boys-girls-winter-coat/7812996104.html'},
#  {'title': 'boys / girls dark blue rain boots size 13-1',
#   'price': '$12',
#   'category': 'shoes',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-boys-girls-dark-blue-rain/7812996023.html'},
#  {'title': 'waugh harley-davidson xl staff shirts',
#   'price': '$15',
#   'category': 'upper body',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-waugh-harley-davidson-xl-staff/7817408055.html'},
#  {'title': 'xs demon slayer hoodie',
#   'price': '$20',
#   'category': 'warmer wear',
#   'location': 'ruckersville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/quinque-xs-demon-slayer-hoodie/7817286143.html'},
#  {'title': 'patagonia brodeo beanie',
#   'price': '$30',
#   'category': 'other',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-patagonia-brodeo-beanie/7817083179.html'},
#  {'title': 'jack georges leather briefcase',
#   'price': '$220',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-jack-georges-leather/7811057192.html'},
#  {'title': 'tumi alpha 2 garment bag 2 wheeled carry-on - black ballistic nylon',
#   'price': '$265',
#   'category': 'bags',
#   'location': 'charlottesville - ivy',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-tumi-alpha-garment-bag/7816533426.html'},
#  {'title': 'men’s timberland boots',
#   'price': '$80',
#   'category': 'shoes',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/quinque-mens-timberland-boots/7816519484.html'},
#  {'title': 'men’s air jordan dub-zero black/black taupe - size 12',
#   'price': '$170',
#   'category': 'other',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/quinque-mens-air-jordan-dub-zero-black/7816518926.html'},
#  {'title': 'brand new men’s haix boots - size 12',
#   'price': '$150',
#   'category': 'shoes',
#   'location': 'ruckersville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/quinque-brand-new-mens-haix-boots-size/7816518067.html'},
#  {'title': 'vasque womens hiking boots 9w',
#   'price': '$20',
#   'category': 'shoes',
#   'location': 'free union',
#   'link': 'https://charlottesville.craigslist.org/clo/d/free-union-vasque-womens-hiking-boots-9w/7809273481.html'},
#  {'title': 'carhartt bibs',
#   'price': '$50',
#   'category': 'other',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-carhartt-bibs/7815929911.html'},
#  {'title': 'jordan',
#   'price': '$20',
#   'category': 'other',
#   'location': 'gordonsville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/gordonsville-jordan/7812626096.html'},
#  {'title': 'mini closet clean-out; lane bryant coats',
#   'price': '$100',
#   'category': 'warmer wear',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/fishersville-mini-closet-clean-out-lane/7815836274.html'},
#  {'title': 'shelving and hanging clothing storage',
#   'price': '$20',
#   'category': 'other',
#   'location': 'scottsville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/scottsville-shelving-and-hanging/7815794919.html'},
#  {'title': 'easy rider leather motorcycle boots',
#   'price': '$40',
#   'category': 'shoes',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-easy-rider-leather/7808082516.html'},
#  {'title': "columbia men's winter boots - new",
#   'price': '$75',
#   'category': 'shoes',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-columbia-mens-winter/7808082432.html'},
#  {'title': 'vera wang bridesmaid dress',
#   'price': '$80',
#   'category': 'dress',
#   'location': 'hydraulic rd.',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-vera-wang-bridesmaid/7815382489.html'},
#  {'title': 'knit scarf new',
#   'price': '$8',
#   'category': 'other',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/troy-knit-scarf-new/7810275525.html'},
#  {'title': 'synergy pants large new tag attached',
#   'price': '$30',
#   'category': 'pants',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/troy-synergy-pants-large-new-tag/7810157797.html'},
#  {'title': "jessica simpson strappy wedges - women's 10m",
#   'price': '$30',
#   'category': 'other',
#   'location': 'charlottesville, va',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-jessica-simpson-strappy/7815034591.html'},
#  {'title': "francosarto green wedges - women's 9",
#   'price': '$35',
#   'category': 'other',
#   'location': 'charlottesville, va',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-francosarto-green/7815032285.html'},
#  {'title': "women's size 39 ( us - 9) brown booties",
#   'price': '$60',
#   'category': 'other',
#   'location': 'charlottesville, va',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-womens-size-39-us-brown/7815030432.html'},
#  {'title': 'carhartt coverall insulated',
#   'price': '$100',
#   'category': 'other',
#   'location': 'scottsville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/scottsville-carhartt-coverall-insulated/7815013656.html'},
#  {'title': 'equestrian boots',
#   'price': '$60',
#   'category': 'shoes',
#   'location': 'keswick',
#   'link': 'https://charlottesville.craigslist.org/clo/d/keswick-equestrian-boots/7814833828.html'},
#  {'title': 'purse - (reduced) l.k. bennett',
#   'price': '$50',
#   'category': 'bags',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-purse-reduced-lk-bennett/7814767875.html'},
#  {'title': "new men's 100% cashmere topcoat",
#   'price': '$250',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-new-mens-100-cashmere/7807498930.html'},
#  {'title': "men's dark brown lined winter jacket",
#   'price': '$60',
#   'category': 'warmer wear',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-mens-dark-brown-lined/7807498614.html'},
#  {'title': "men's camel brown lined winter jacket",
#   'price': '$60',
#   'category': 'warmer wear',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-mens-camel-brown-lined/7807498554.html'},
#  {'title': "new men's belted raincoat/overcoat",
#   'price': '$200',
#   'category': 'other',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-new-mens-belted/7807498420.html'},
#  {'title': "keen hiking shoes -- women's 8.5",
#   'price': '$20',
#   'category': 'shoes',
#   'location': '29 n',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-keen-hiking-shoes/7814353257.html'},
#  {'title': 'elderly care items',
#   'price': '$0',
#   'category': 'other',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-elderly-care-items/7813723600.html'},
#  {'title': 'elderly care items',
#   'price': '$0',
#   'category': 'other',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-elderly-care-items/7813724621.html'},
#  {'title': 'small lot size 14 youth little girls clothes crop jeans & 3 tops',
#   'price': '$20',
#   'category': 'pants',
#   'location': 'earlysville or charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/small-lot-size-14-youth-little-girls/7814196099.html'},
#  {'title': 'brand new nike kd16 wanda mint foam basketball shoes',
#   'price': '$50',
#   'category': 'shoes',
#   'location': 'orange',
#   'link': 'https://charlottesville.craigslist.org/clo/d/orange-brand-new-nike-kd16-wanda-mint/7807230430.html'},
#  {'title': 'worn once wedding dress',
#   'price': '$100',
#   'category': 'dress',
#   'location': 'rio road',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-worn-once-wedding-dress/7814070395.html'},
#  {'title': 'harley-davidson xl t shirts new w/o tags',
#   'price': '$15',
#   'category': 'upper body',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-harley-davidson-xl-shirts-new-o/7813828927.html'},
#  {'title': 'harley-davidson t shirts xl new w/tags',
#   'price': '$25',
#   'category': 'upper body',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-harley-davidson-shirts-xl-new/7813828469.html'},
#  {'title': 'cream ivory lace skirt by joey b - youth girls small s',
#   'price': '$8',
#   'category': 'dress',
#   'location': 'earlysville / charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/earlysville-cream-ivory-lace-skirt-by/7813810320.html'},
#  {'title': 'leather jacket - xl wilson leather',
#   'price': '$20',
#   'category': 'warmer wear',
#   'location': 'charlottesville',
#   'link': 'https://charlottesville.craigslist.org/clo/d/charlottesville-leather-jacket-xl/7813796786.html'},
#  {'title': 'women’s leather jacket',
#   'price': '$40',
#   'category': 'warmer wear',
#   'location': 'zion crossroads',
#   'link': 'https://charlottesville.craigslist.org/clo/d/montpelier-station-womens-leather-jacket/7806670519.html'},
#  {'title': '25 harley-davidson deco spots 1/2" round 93024-88',
#   'price': '$25',
#   'category': 'other',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-25-harley-davidson-deco-spots-2/7812965565.html'},
#  {'title': "levi's 505 regular fit jeans 3 pairs w36 l32 new",
#   'price': '$85',
#   'category': 'pants',
#   'location': 'madison',
#   'link': 'https://charlottesville.craigslist.org/clo/d/pratts-levis-505-regular-fit-jeans/7812965231.html'},
#  {'title': 'satin french maids apron',
#   'price': '$5',
#   'category': 'other',
#   'location': 'unknown',
#   'link': 'https://charlottesville.craigslist.org/clo/d/troy-satin-french-maids-apron/7810406860.html'},
#  {'title': 'brand new loungefly gizmo mini backpack & wallet set',
#   'price': '$125',
#   'category': 'bags',
#   'location': 'crozet',
#   'link': 'https://charlottesville.craigslist.org/clo/d/crozet-brand-new-loungefly-gizmo-mini/7812756023.html'},
#  {'title': 'stitch shoes',
#   'price': '$30',
#   'category': 'shoes',
#   'location': 'keswick',
#   'link': 'https://charlottesville.craigslist.org/clo/d/keswick-stitch-shoes/7812748757.html'},
#  {'title': 'minnie mouse shoes',
#   'price': '$30',
#   'category': 'shoes',
#   'location': 'keswick',
#   'link': 'https://charlottesville.craigslist.org/clo/d/keswick-minnie-mouse-shoes/7812745091.html'},
#  {'title': 'new sneakers  size 10 1/2 from walmart',
#   'price': '$10',
#   'category': 'shoes',
#   'location': 'waynesboro',
#   'link': 'https://charlottesville.craigslist.org/clo/d/waynesboro-new-sneakers-size-from/7812524136.html'}]

# %%
chart=pd.DataFrame.from_dict(data)
chart['price'] = chart['price'].str.replace('$','')
chart['price'] = chart['price'].str.replace(',','')
chart['price']=pd.to_numeric(chart['price'],errors='coerce')
chart['location']=chart['location'].str.replace(', va','')
chart['location']=chart['location'].str.replace(' - ivy','')
chart['location']=chart['location'].str.replace('.','')
chart['location']=chart['location'].str.replace('downtown, ','')
chart['location']=chart['location'].str.replace('cville','charlottesville')
chart['location']=chart['location'].str.replace("c'ville",'charlottesville')
chart['location']=chart['location'].astype('category')
#print(chart['price'].describe()) #cheap! O.o
plt.xticks(rotation=45,ha='right',fontsize=8)
loc_graph=chart['location'].hist(grid=False)
loc_graph.set(title="Locations Sold",xlabel="Locations",ylabel="Frequency")
# Out:
# [Text(0.5, 1.0, 'Locations Sold'),
#  Text(0.5, 0, 'Locations'),
#  Text(0, 0.5, 'Frequency')]

# %%
cat_graph=chart['category'].hist(grid=False)
plt.xticks(rotation=45,ha='right')
loc_graph.set(title="Clothings Sold",xlabel="Category",ylabel="Frequency")
# Out:
# [Text(0.5, 1.0, 'Clothings Sold'),
#  Text(0.5, 24.0, 'Category'),
#  Text(28.80573954576642, 0.5, 'Frequency')]

# %%
sns.boxplot(chart['price'])

#There's a Louis Voutan bag sold on Craigslist for $123,456,789, which is why the boxplot is completely lopsided.
  #Could be counterfit and a scam though, cause why are they selling on Craigslist?
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# People seem to sell old clothes on Craigslist pretty often in the Charlottesville area. Out of all locations, Charlottesville is most common, which is to be expected since the radius of search is centered on Charlottesville. People tend to sell more warmer wear, which includes jackets, coats, hoodies and sweaters, though that pales in comparison to the miscellaneous items in other that weren't sorted into one of the other categories. Shoes are also pretty common. Reasons could be incorrect size, disliking the style, uncomfortable, doesn't have enough use to keep, etc.
# Prices for clothes on Craigslist seems to lean on the cheaper end, with free items being offered rather frequently. However, there are a couple outliers like the Louis Voutan bag sold on Craigslist for $123,456,789, which is why the boxplot is completely lopsided. I personally wouldn't trust buying that bag since it could be counterfit and a scam, cause why are they selling on Craigslist and why did they buy it in the first place if it wasn't to resell?
